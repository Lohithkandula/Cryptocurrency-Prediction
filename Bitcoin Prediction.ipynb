# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense,LSTM,Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
data_dir='BTC-2021.csv'
df=pd.read_csv(data_dir)

# %%
df.head()
# Out:
#          unix                 date   symbol      open      high       low  \
# 0  1646106180  2022-03-01 03:43:00  BTC/USD  43046.58  43046.58  43046.58
# 1  1646106060  2022-03-01 03:41:00  BTC/USD  43018.23  43046.59  43018.23
# 2  1646106000  2022-03-01 03:40:00  BTC/USD  43022.24  43022.24  43016.03
# 3  1646105940  2022-03-01 03:39:00  BTC/USD  43035.16  43035.16  42999.44
# 4  1646105880  2022-03-01 03:38:00  BTC/USD  43077.82  43077.82  43049.46
#
#       close  Volume BTC    Volume USD
# 0  43046.58    0.000000      0.000000
# 1  43046.58    0.142977   6154.673021
# 2  43016.03    0.009230    397.037957
# 3  42999.44    0.820950  35300.390268
# 4  43049.46    0.022210    956.143143

# %%
df.tail()
# Out:
#               unix                 date   symbol      open      high  \
# 610777  1609459500  2021-01-01 00:05:00  BTC/USD  29021.86  29023.38
# 610778  1609459440  2021-01-01 00:04:00  BTC/USD  29048.13  29057.73
# 610779  1609459380  2021-01-01 00:03:00  BTC/USD  29037.68  29069.39
# 610780  1609459320  2021-01-01 00:02:00  BTC/USD  29069.80  29073.02
# 610781  1609459260  2021-01-01 00:01:00  BTC/USD  29007.31  29086.90
#
#              low     close  Volume BTC     Volume USD
# 610777  28982.33  28999.50    1.062360   30807.899250
# 610778  29035.61  29045.19    1.446538   42014.959434
# 610779  29019.00  29048.13    2.189621   63604.382387
# 610780  29028.14  29035.89    3.030301   87987.499279
# 610781  29007.31  29083.47   14.561951  423512.060397

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610782 entries, 0 to 610781
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   unix        610782 non-null  int64
#  1   date        610782 non-null  object
#  2   symbol      610782 non-null  object
#  3   open        610782 non-null  float64
#  4   high        610782 non-null  float64
#  5   low         610782 non-null  float64
#  6   close       610782 non-null  float64
#  7   Volume BTC  610782 non-null  float64
#  8   Volume USD  610782 non-null  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 41.9+ MB

# %%
df.describe()
# Out:
#                unix           open           high            low  \
# count  6.107820e+05  610782.000000  610782.000000  610782.000000
# mean   1.627783e+09   46482.265381   46509.783597   46454.085712
# std    1.057906e+07    9453.990285    9454.798088    9453.135638
# min    1.609459e+09   28093.810000   28397.520000   27734.000000
# 25%    1.618621e+09   38129.052500   38157.882500   38099.437500
# 50%    1.627783e+09   46666.960000   46697.745000   46636.710000
# 75%    1.636944e+09   54907.797500   54938.655000   54877.405000
# max    1.646106e+09   69000.000000   69000.000000   68799.990000
#
#                close     Volume BTC    Volume USD
# count  610782.000000  610782.000000  6.107820e+05
# mean    46482.567211       3.165254  1.389474e+05
# std      9454.107853       7.893321  3.298068e+05
# min     28073.030000       0.000000  0.000000e+00
# 25%     38129.137500       0.193192  8.859586e+03
# 50%     46667.295000       0.924971  4.190121e+04
# 75%     54907.412500       2.989888  1.349341e+05
# max     69000.000000     398.565948  1.396792e+07

# %%
df['date']=pd.to_datetime(df['date'])
df.set_index('date',inplace=True)

# %%
plt.figure(figsize=(16,6))
df[r'open'].plot()
df[r'close'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title('Opening & closing Price of Bitcoin')
plt.legend(['Open Price','Close Price'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,6))
df[r'high'].plot()
df[r'low'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title('high & low Price of Bitcoin')
plt.legend(['High Price','Low Price'])
plt.tight_layout()
plt.show()

# %%
n_cols=1
dataset=df[r'close']
dataset=pd.DataFrame(dataset)
data=dataset.values
data.shape
# Out:
# (610782, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(np.array(data))

# %%
train_size=int(len(data)*0.75)
test_size=len(data)-train_size
print('Train Size:',train_size,'Test Size:',test_size)
# Out:
# Train Size: 458086 Test Size: 152696

# %%
train_data=scaled_data[0:train_size, :]
train_data.shape
# Out:
# (458086, 1)

# %%
x_train=[]
y_train=[]
time_steps=60
n_cols=1
for i in range(time_steps,len(train_data)):
    x_train.append(train_data[i-time_steps:i,:n_cols])
    y_train.append(train_data[i,:n_cols])
    if i<=time_steps:
        print('X_Train',x_train)
        print('Y_Train',y_train)
# Out:
# X_Train [array([[0.36586021],
#        [0.36586021],
#        [0.36511376],
#        [0.36470841],
#        [0.36593058],
#        [0.36689474],
#        [0.36693457],
#        [0.36675425],
#        [0.36712686],
#        [0.36712686],
#        [0.36735287],
#        [0.36735287],
#        [0.36700713],
#        [0.36633032],
#        [0.36588856],
#        [0.36413861],
#        [0.36376429],
#        [0.36477829],
#        [0.36546805],
#        [0.36501358],
#        [0.36496227],
#        [0.36432651],
#        [0.36434214],
#        [0.36430574],
#        [0.36325484],
#        [0.36277863],
#        [0.36426933],
#        [0.36440396],
#        [0.36407386],
#        [0.36548907],
#        [0.36593156],
#        [0.36699492],
#        [0.36689425],
#        [0.36581672],
#        [0.3673927 ],
#        [0.36714079],
#        [0.36689621],
#        [0.36688936],
#        [0.36723901],
#        [0.36727542],
#        [0.36790654],
#        [0.36819168],
#        [0.36866106],
#        [0.36865812],
#        [0.36901583],
#        [0.36850492],
#        [0.36886679],
#        [0.36807489],
#        [0.36749068],
#        [0.36767369],
#        [0.36822882],
#        [0.36695045],
#        [0.36772036],
#        [0.36735605],
#        [0.36807489],
#        [0.36841696],
#        [0.36833096],
#        [0.36808442],
#        [0.36798864],
#        [0.36790899]])]
# Y_Train [array([0.36779121])]

# %%
x_train,y_train=np.array(x_train),np.array(y_train)

# %%
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],n_cols))

# %%
x_train.shape,y_train.shape
# Out:
# ((458026, 60, 1), (458026, 1))

# %%
model=Sequential([
    LSTM(50,return_sequences=True,input_shape=(x_train.shape[1],n_cols)),
    LSTM(64,return_sequences=False),
    Dense(32),
    Dense(16),
    Dense(n_cols)
])
model.compile(optimizer='adam',loss='mse',metrics='mean_absolute_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 64)                29440
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 42465 (165.88 KB)
# Trainable params: 42465 (165.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history=model.fit(x_train,y_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 14314/14314 [==============================] - 839s 58ms/step - loss: 8.0215e-05 - mean_absolute_error: 0.0029
# Epoch 2/100
# 14314/14314 [==============================] - 964s 67ms/step - loss: 5.7700e-06 - mean_absolute_error: 0.0018
# Epoch 3/100
# 14314/14314 [==============================] - 895s 63ms/step - loss: 4.6233e-06 - mean_absolute_error: 0.0016
# Epoch 4/100
# 14314/14314 [==============================] - 882s 62ms/step - loss: 4.1264e-06 - mean_absolute_error: 0.0015
# Epoch 5/100
# 14314/14314 [==============================] - 920s 64ms/step - loss: 3.8858e-06 - mean_absolute_error: 0.0014
# Epoch 6/100
# 14314/14314 [==============================] - 849s 59ms/step - loss: 3.5428e-06 - mean_absolute_error: 0.0014
# Epoch 7/100
# 14314/14314 [==============================] - 832s 58ms/step - loss: 3.3389e-06 - mean_absolute_error: 0.0013
# Epoch 8/100
# 14314/14314 [==============================] - 920s 64ms/step - loss: 3.2442e-06 - mean_absolute_error: 0.0013
# Epoch 88/100
# 14314/14314 [==============================] - 787s 55ms/step - loss: 2.2124e-06 - mean_absolute_error: 0.0010
# Epoch 89/100
# 14314/14314 [==============================] - 816s 57ms/step - loss: 2.2082e-06 - mean_absolute_error: 0.0010
# Epoch 90/100
# 14314/14314 [==============================] - 804s 56ms/step - loss: 2.2216e-06 - mean_absolute_error: 0.0010
# Epoch 91/100
# 14314/14314 [==============================] - 1073s 75ms/step - loss: 2.2016e-06 - mean_absolute_error: 0.0010
# Epoch 92/100
# 14314/14314 [==============================] - 1093s 76ms/step - loss: 2.2211e-06 - mean_absolute_error: 0.0010
# Epoch 93/100
# 14314/14314 [==============================] - 983s 69ms/step - loss: 2.2010e-06 - mean_absolute_error: 0.0010
# Epoch 94/100
# 14314/14314 [==============================] - 897s 63ms/step - loss: 2.1833e-06 - mean_absolute_error: 0.0010
# Epoch 95/100
# 14314/14314 [==============================] - 886s 62ms/step - loss: 2.1969e-06 - mean_absolute_error: 0.0010
# Epoch 96/100
# 14314/14314 [==============================] - 874s 61ms/step - loss: 2.2025e-06 - mean_absolute_error: 0.0010
# Epoch 97/100
# 14314/14314 [==============================] - 1177s 82ms/step - loss: 2.1925e-06 - mean_absolute_error: 0.0010
# Epoch 98/100
# 14314/14314 [==============================] - 865s 60ms/step - loss: 2.1816e-06 - mean_absolute_error: 0.0010
# Epoch 99/100
# 14314/14314 [==============================] - 849s 59ms/step - loss: 2.1741e-06 - mean_absolute_error: 0.0010
# Epoch 100/100
# 14314/14314 [==============================] - 858s 60ms/step - loss: 2.1749e-06 - mean_absolute_error: 0.0010

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
time_steps=60
test_data=scaled_data[train_size-time_steps:,:]
x_test=[]
y_test=[]
n_cols=1
for i in range(time_steps,len(test_data)):
    x_test.append(test_data[i-time_steps:i,0:n_cols])
    y_test.append(test_data[i,0:n_cols])
x_test,y_test=np.array(x_test),np.array(y_test)
x_test=np.reshape(x_test,(x_test.shape[0],x_test.shape[1],n_cols))

# %%
x_test.shape,y_test.shape
# Out:
# ((152696, 60, 1), (152696, 1))

# %%
predictions=model.predict(x_test)
# Out:
# 4772/4772 [==============================] - 170s 35ms/step

# %%
predictions=scaler.inverse_transform(predictions)
predictions.shape
# Out:
# (152696, 1)

# %%
y_test=scaler.inverse_transform(y_test)
rmse=np.sqrt(np.mean(y_test-predictions)**2).round(2)
rmse
# Out:
# 33.85

# %%
preds_acts=pd.DataFrame(data={'Predictions':predictions.flatten(),'Actuals':y_test.flatten()})
preds_acts
# Out:
#          Predictions   Actuals
# 0       61636.382812  61531.62
# 1       61568.867188  61511.61
# 2       61549.261719  61557.64
# 3       61592.320312  61502.98
# 4       61539.625000  61505.71
# ...              ...       ...
# 152691  29030.080078  28999.50
# 152692  29032.285156  29045.19
# 152693  29078.724609  29048.13
# 152694  29080.982422  29035.89
# 152695  29069.429688  29083.47
#
# [152696 rows x 2 columns]

# %%
plt.figure(figsize=(16,6))
plt.plot(preds_acts['Predictions'])
plt.plot(preds_acts['Actuals'])
plt.legend(['Predictions','Actuals'])
plt.show()

# %%
train=dataset.iloc[:train_size,0:1]
test=dataset.iloc[train_size:, 0:1]
test ['Predictions']=predictions
plt.figure(figsize=(16,6))
plt.title('Bitcoin stock price predictions',fontsize=20)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close',fontsize=18)
plt.plot(train[r'close'],linewidth=3)
plt.plot(test[r'close'],linewidth=3)
plt.plot(test["Predictions"],linewidth=3)
plt.legend(['Train','Test','Predictions'])
